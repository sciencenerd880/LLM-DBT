# %%
pip install --upgrade --force-reinstall torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...
#      ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#      ---------------------------------------- 6.2/6.2 MB 31.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#      ------------------------------------- 536.2/536.2 kB 17.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 GB 36.4 MB/s eta 0:01:09
#    ---------------------------------------- 0.0/2.5 GB 37.4 MB/s eta 0:01:07
#    ---------------------------------------- 0.0/2.5 GB 38.3 MB/s eta 0:01:05
#    ---------------------------------------- 0.0/2.5 GB 37.0 MB/s eta 0:01:07
#     --------------------------------------- 0.0/2.5 GB 37.8 MB/s eta 0:01:05
#     --------------------------------------- 0.0/2.5 GB 38.8 MB/s eta 0:01:04
#     --------------------------------------- 0.1/2.5 GB 38.4 MB/s eta 0:01:04
# ...

# %%
import torch
print(torch.version.cuda)
# torch.cuda.is_available()
# Out:
# 12.6

# %%
import whisper

model = whisper.load_model('base', device='cuda')

# %%
import os
folder_name = "D:\Shark_Tank_Data\Shark Tank - Season 9-13 (720p)"

# Transcribe an audio file
for folder in os.listdir(folder_name):
    print(folder)
    for file in os.listdir(folder):
        text_list = []
        if file.endswith(".mkv"):
            print(file)
            if file+".txt" in os.listdir(folder):
                continue
            result = model.transcribe(folder+"/"+file)
            for i in result['segments']:
                text_list.append(i['text'])
            full_text = '\n'.join(text_list)
            with open(folder_name+"/"+file+".txt", "w",encoding = 'utf-8') as f:
                f.write(full_text)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\derek\AppData\Local\Temp\ipykernel_138824\1312334940.py:2: SyntaxWarning: invalid escape sequence '\S'
#   folder_name = "D:\Shark_Tank_Data\Shark Tank - Season 15 (720p)"
# Shark Tank — 15x01.mkv
# Shark Tank — 15x02.mkv
# Shark Tank — 15x03.mkv
# Shark Tank — 15x04.mkv
# Shark Tank — 15x05.mkv
# Shark Tank — 15x06.mkv
# Shark Tank — 15x07.mkv
# Shark Tank — 15x08.mkv
# Shark Tank — 15x09.mkv
# Shark Tank — 15x10.mkv
# Shark Tank — 15x11.mkv
# Shark Tank — 15x12.mkv
# Shark Tank — 15x13.mkv
# Shark Tank — 15x14.mkv
# Shark Tank — 15x15.mkv
# Shark Tank — 15x16.mkv
# Shark Tank — 15x17.mkv
# Shark Tank — 15x18.mkv
# Shark Tank — 15x19.mkv
# Shark Tank — 15x20.mkv
# Shark Tank — 15x21.mkv
# Shark Tank — 15x22.mkv
